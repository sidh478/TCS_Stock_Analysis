# %% [markdown]
# # TCS_Stock_Analysis

# %%
# !pip install nsepy
# Out:
# Requirement already satisfied: nsepy in c:\users\harsh\anaconda3\lib\site-packages (0.8)
# Requirement already satisfied: click in c:\users\harsh\anaconda3\lib\site-packages (from nsepy) (8.0.4)
# Requirement already satisfied: requests in c:\users\harsh\anaconda3\lib\site-packages (from nsepy) (2.28.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\harsh\anaconda3\lib\site-packages (from nsepy) (4.11.1)
# Requirement already satisfied: lxml in c:\users\harsh\anaconda3\lib\site-packages (from nsepy) (4.9.1)
# Requirement already satisfied: pandas in c:\users\harsh\anaconda3\lib\site-packages (from nsepy) (1.4.4)
# Requirement already satisfied: numpy in c:\users\harsh\anaconda3\lib\site-packages (from nsepy) (1.21.5)
# Requirement already satisfied: six in c:\users\harsh\anaconda3\lib\site-packages (from nsepy) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\harsh\anaconda3\lib\site-packages (from beautifulsoup4->nsepy) (2.3.1)
# Requirement already satisfied: colorama in c:\users\harsh\anaconda3\lib\site-packages (from click->nsepy) (0.4.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\harsh\anaconda3\lib\site-packages (from pandas->nsepy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsh\anaconda3\lib\site-packages (from pandas->nsepy) (2022.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\harsh\anaconda3\lib\site-packages (from requests->nsepy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harsh\anaconda3\lib\site-packages (from requests->nsepy) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harsh\anaconda3\lib\site-packages (from requests->nsepy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\harsh\anaconda3\lib\site-packages (from requests->nsepy) (1.26.11)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import nsepy as nse
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
from datetime import date
import datetime
current_time=datetime.datetime.now()

# %%
tcs=nse.get_history(symbol='TCS',start=date(2010,1,1),end=date(current_time.year,current_time.month,current_time.day))

# %%
tcs.head()
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2010-01-04    TCS     EQ      750.25  754.80  758.90  749.05  752.25  751.65
# 2010-01-05    TCS     EQ      751.65  755.00  759.55  746.55  748.70  751.85
# 2010-01-06    TCS     EQ      751.85  751.85  752.20  733.00  737.00  734.85
# 2010-01-07    TCS     EQ      734.85  735.50  739.40  711.00  711.85  714.40
# 2010-01-08    TCS     EQ      714.40  716.00  718.50  696.50  696.50  699.80
#
#               VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2010-01-04  753.34   981841  7.396555e+13     NaN              570284
# 2010-01-05  751.53  1007244  7.569694e+13     NaN              513287
# 2010-01-06  738.35  1674588  1.236424e+14     NaN             1010023
# 2010-01-07  717.63  3237446  2.323275e+14     NaN             1987073
# 2010-01-08  704.68  3024089  2.131008e+14     NaN             1944945
#
#             %Deliverble
# Date
# 2010-01-04       0.5808
# 2010-01-05       0.5096
# 2010-01-06       0.6031
# 2010-01-07       0.6138
# 2010-01-08       0.6432

# %%
tcs.shape
# Out:
# (3275, 14)

# %%
tcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3275 entries, 2010-01-04 to 2023-03-08
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              3275 non-null   object
#  1   Series              3275 non-null   object
#  2   Prev Close          3275 non-null   float64
#  3   Open                3275 non-null   float64
#  4   High                3275 non-null   float64
#  5   Low                 3275 non-null   float64
#  6   Last                3275 non-null   float64
#  7   Close               3275 non-null   float64
#  8   VWAP                3275 non-null   float64
#  9   Volume              3275 non-null   int64
#  10  Turnover            3275 non-null   float64
#  11  Trades              2920 non-null   float64
#  12  Deliverable Volume  3275 non-null   int64
#  13  %Deliverble         3275 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 383.8+ KB

# %%
tcs.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  3275.000000  3275.000000  3275.000000  3275.000000  3275.000000
# mean   2186.160473  2187.614672  2210.470473  2163.552977  2187.066855
# std     795.420571   795.793263   801.776267   789.070276   795.412261
# min     699.550000   704.000000   714.000000   685.250000   696.500000
# 25%    1467.950000  1463.050000  1478.500000  1450.075000  1469.175000
# 50%    2242.300000  2244.000000  2264.000000  2216.000000  2242.000000
# 75%    2624.575000  2623.950000  2650.300000  2600.000000  2624.400000
# max    4019.150000  4033.950000  4043.000000  3980.000000  4025.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  3275.000000  3275.000000  3.275000e+03  3.275000e+03    2920.000000
# mean   2186.973740  2187.156501  1.940795e+06  4.386261e+14   93919.606164
# std     795.294796   795.422943  1.668815e+06  4.579311e+14   61604.417809
# min     699.550000   704.680000  2.801700e+04  3.989508e+12    1219.000000
# 25%    1468.750000  1466.165000  9.807195e+05  1.747421e+14   50109.750000
# 50%    2242.650000  2241.920000  1.526692e+06  2.992470e+14   79057.000000
# 75%    2625.375000  2625.615000  2.410140e+06  5.773004e+14  121694.750000
# max    4019.150000  4010.330000  4.403358e+07  1.268362e+16  704881.000000
#
#        Deliverable Volume  %Deliverble
# count        3.275000e+03  3275.000000
# mean         1.067544e+06     0.577120
# std          8.942112e+05     0.120788
# min          7.765000e+03     0.121400
# 25%          5.811865e+05     0.499050
# 50%          8.867270e+05     0.583700
# 75%          1.335367e+06     0.663500
# max          3.155626e+07     0.899300

# %%
tcs.isnull().sum()
# Out:
# Symbol                  0
# Series                  0
# Prev Close              0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# VWAP                    0
# Volume                  0
# Turnover                0
# Trades                355
# Deliverable Volume      0
# %Deliverble             0
# dtype: int64

# %%
sns.heatmap(data=tcs.isnull(), cmap='plasma', cbar=False);

# %%
tcs['Trades']=tcs['Trades'].fillna(method='bfill')

# %%
tcs.isnull().sum()
# Out:
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
sns.heatmap(data=tcs.isnull(), cmap='plasma', cbar=False);

# %%
tcs.duplicated().sum()
# Out:
# 3

# %%
tcs.drop_duplicates(inplace=True)

# %%
tcs.duplicated().sum()
# Out:
# 0

# %%
#since 'Symbol' and 'Series' is constant value we can drop it
tcs.drop(['Symbol','Series'],axis=1,inplace=True)

# %%
tcs.head()
# Out:
#             Prev Close    Open    High     Low    Last   Close    VWAP  \
# Date
# 2010-01-04      750.25  754.80  758.90  749.05  752.25  751.65  753.34
# 2010-01-05      751.65  755.00  759.55  746.55  748.70  751.85  751.53
# 2010-01-06      751.85  751.85  752.20  733.00  737.00  734.85  738.35
# 2010-01-07      734.85  735.50  739.40  711.00  711.85  714.40  717.63
# 2010-01-08      714.40  716.00  718.50  696.50  696.50  699.80  704.68
#
#              Volume      Turnover   Trades  Deliverable Volume  %Deliverble
# Date
# 2010-01-04   981841  7.396555e+13  24427.0              570284       0.5808
# 2010-01-05  1007244  7.569694e+13  24427.0              513287       0.5096
# 2010-01-06  1674588  1.236424e+14  24427.0             1010023       0.6031
# 2010-01-07  3237446  2.323275e+14  24427.0             1987073       0.6138
# 2010-01-08  3024089  2.131008e+14  24427.0             1944945       0.6432

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(10,10))
sns.heatmap(tcs.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# we observe from scatter plot and heat map
#
# 1.Prev Close,open,High,Low,Last,Close,VWAP is higly co related with each other.
#
# 2.Volume is highly corelated with Turnover,Deliverable Volume.
#
# 3.Trades is moderatly co related with volume,Turnover,Deliverable volume.
#
# 4.Deliverable Volume is highly co related with Volume,Turnover and moderatly with Trades.
#
# 5.%Deliverable Volume is moderatly co related with Deliverable Volume

# %%
for i in tcs.columns:
    sns.histplot(tcs[i],kde=True)
    plt.show()

# %% [markdown]
# 1.only count v/s %Deliverble is  almost normally distributed.
#
# 2.count v/s trades is right skewed
#
# 3.count v/s deliverable,turnover,volume data having less variance and right skewed

# %%
for i in tcs.columns:
        sns.boxplot(tcs[i])
        plt.xlabel(i)
        plt.show()

# %% [markdown]
# 1.There are no outliers in Prev Close ,open,High,Low,Last,Close,VWAP.
#
# 2.Rest all there is outliers

# %%
for i in tcs.columns:
    tcs.plot.line(y=i,use_index=True)
    plt.ylabel(i)
    plt.show()

# %%
plt.figure(figsize=(10,10))
tcs.plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
tcs['Date'] = tcs.index
tcs.head()
# Out:
#             Prev Close    Open    High     Low    Last   Close    VWAP  \
# Date
# 2010-01-04      750.25  754.80  758.90  749.05  752.25  751.65  753.34
# 2010-01-05      751.65  755.00  759.55  746.55  748.70  751.85  751.53
# 2010-01-06      751.85  751.85  752.20  733.00  737.00  734.85  738.35
# 2010-01-07      734.85  735.50  739.40  711.00  711.85  714.40  717.63
# 2010-01-08      714.40  716.00  718.50  696.50  696.50  699.80  704.68
#
#              Volume      Turnover   Trades  Deliverable Volume  %Deliverble  \
# Date
# 2010-01-04   981841  7.396555e+13  24427.0              570284       0.5808
# 2010-01-05  1007244  7.569694e+13  24427.0              513287       0.5096
# 2010-01-06  1674588  1.236424e+14  24427.0             1010023       0.6031
# 2010-01-07  3237446  2.323275e+14  24427.0             1987073       0.6138
# 2010-01-08  3024089  2.131008e+14  24427.0             1944945       0.6432
#
#                   Date
# Date
# 2010-01-04  2010-01-04
# 2010-01-05  2010-01-05
# 2010-01-06  2010-01-06
# 2010-01-07  2010-01-07
# 2010-01-08  2010-01-08

# %%
tcs['Date']=pd.to_datetime(tcs['Date'])

# %%
tcs=tcs.set_index('Date')

# %%
tcs.resample('Y').mean()
# Out:
#              Prev Close         Open         High          Low         Last  \
# Date
# 2010-12-31   861.241667   862.790873   873.704365   851.335714   862.956151
# 2011-12-31  1116.768826  1117.724899  1132.737652  1101.337045  1116.798381
# 2012-12-31  1237.955976  1238.302191  1251.667131  1224.401793  1238.171315
# 2013-12-31  1688.394400  1689.571400  1711.884400  1671.836800  1691.730800
# 2014-12-31  2368.155533  2371.478484  2396.937705  2343.805533  2369.809836
# 2015-12-31  2538.207460  2542.172782  2563.580444  2514.408468  2538.039718
# 2016-12-31  2419.522065  2418.992105  2442.333198  2392.198785  2419.567611
# 2017-12-31  2474.425000  2475.062298  2499.661895  2452.465524  2475.531048
